# %% [markdown]
# # Ini

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import re

# %%
df = pd.read_excel('../ini_data/datamon.xlsx')
df.sample(10)
# Out:
#                                Наименование        Дата поставки Дата заказа  \
# 1255             ТОКОПРИЕМНИК ТКЭ 16-5 УХЛ2  2018-08-20 00:00:00  2018-07-09
# 3854                     Вал 3532.10.01.011  2021-07-20 00:00:00  2021-03-26
# 1106                  Рычаг  3711.01.02.050  2018-05-05 00:00:00  2018-03-30
# 2111              Звездочка 3588.35.01.004   2020-08-20 00:00:00  2020-03-30
# 3296                Коромысло 11078.02.010            10.11.2021         NaT
# 2382               Коромысло 3711.21.00.200  2021-01-11 00:00:00  2020-12-30
# 1997               Коромысло 3519.21.00.023  2020-02-17 00:00:00  2019-12-09
# 3897                     Втулка 1080.05.312  2021-07-05 00:00:00  2021-03-05
# 357     ПРОУШИНА 41.55.04.131 НИЖНЕГО ТРОСА  2016-09-25 00:00:00  2016-07-13
# 1729  Подшипник седловой 3546.03.04.000-02   2020-01-10 00:00:00  2019-02-20
#
#       Срок поставки  Плановый срок поставки               Регион  \
# 1255           42.0                   320.0   Республика Карелия
# 3854          116.0                   160.0   Республика Карелия
# 1106           36.0                   220.0   Республика Карелия
# 2111          143.0                   145.0   Республика Карелия
# 3296            NaN                   180.0   Республика Карелия
# 2382           12.0                   180.0   Республика Карелия
# 1997           70.0                   220.0   Мурманская область
# 3897          122.0                   120.0  Вологодская область
# 357            74.0                   180.0   Республика Карелия
# 1729          324.0                   220.0   Республика Карелия
#
#       Объем заказа     Цена, руб  \
# 1255             1  1.619344e+05
# 3854             1  1.121019e+05
# 1106             1  1.617358e+04
# 2111             2  4.371975e+03
# 3296             1  4.490446e+05
# 2382             1  4.442185e+05
# 1997             3  1.687898e+05
# 3897             4  5.382166e+03
# 357              8  1.617834e+03
# 1729             1  6.911688e+06
#
#                                         Условия платежа  \
# 1255  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 60 дней с да...
# 3854  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 45 дней с да...
# 1106                                                NaN
# 2111  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 30 дней с да...
# 3296                                                NaN
# 2382                                                NaN
# 1997  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 15 дней с да...
# 3897                                                NaN
# 357   ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 30 дней с да...
# 1729  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 30 дней с да...
#
#       НРП - нерегламентная потребность (внеплановая закупка)  Поставщик
# 1255                                                NaN            3685
# 3854                                                NaN            4014
# 1106                                                NaN            3961
# 2111                                                NaN            4011
# 3296                                                NaN            4014
# 2382                                                NaN            3961
# 1997                                                NaN            3952
# 3897                                                NaN            3989
# 357                                                 NaN            4011
# 1729                                                NaN            4011

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4015 entries, 0 to 4014
# Data columns (total 11 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Наименование                                            4015 non-null   object
#  1   Дата поставки                                           4005 non-null   object
#  2   Дата заказа                                             2939 non-null   datetime64[ns]
#  3   Срок поставки                                           2939 non-null   float64
#  4   Плановый срок поставки                                  3994 non-null   float64
#  5   Регион                                                  4015 non-null   object
#  6   Объем заказа                                            4015 non-null   int64
#  7   Цена, руб                                               4015 non-null   float64
#  8   Условия платежа                                         2197 non-null   object
#  9   НРП - нерегламентная потребность (внеплановая закупка)  303 non-null    float64
#  10  Поставщик                                               4015 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 345.2+ KB

# %%
df.describe()
# Out:
#        Срок поставки  Плановый срок поставки  Объем заказа     Цена, руб  \
# count     2939.00000             3994.000000   4015.000000  4.015000e+03
# mean       127.45900              170.007762      7.817186  7.182498e+05
# std        123.42362               88.446546     51.075264  4.395519e+06
# min          0.00000               15.000000      1.000000  2.229299e+01
# 25%         49.00000               90.000000      1.000000  2.101911e+04
# 50%         95.00000              180.000000      2.000000  1.121019e+05
# 75%        172.00000              220.000000      4.000000  3.589599e+05
# max        807.00000              470.000000   1500.000000  1.649682e+08
#
#        НРП - нерегламентная потребность (внеплановая закупка)   Поставщик
# count                                              303.0       4015.00000
# mean                                                 1.0       3900.50411
# std                                                  0.0        318.22084
# min                                                  1.0        259.00000
# 25%                                                  1.0       3987.00000
# 50%                                                  1.0       4011.00000
# 75%                                                  1.0       4012.00000
# max                                                  1.0       4014.00000

# %% [markdown]
# # Names

# %%
df.Наименование.nunique()
# Out:
# 1008

# %%
plt.plot(sorted(df.Наименование.value_counts(), reverse=True));

# %%
df['Наименование2'] = df.Наименование.apply(lambda s: s.lower().strip().replace("  ", "").replace('.', '-'))

# %%
df.head()
# Out:
#                         Наименование        Дата поставки Дата заказа  \
# 0  ШКИВ К МПЭ-350-900 3536.19.00.200  2017-04-10 00:00:00  2015-06-09
# 1                СТРЕЛА 1085.05.00СБ  2015-11-10 00:00:00  2015-08-03
# 2            УСТРОЙСТВО КУЭ-3 04УХЛ2  2015-10-27 00:00:00  2015-08-03
# 3                  ВТУЛКА 1080.33.70  2015-08-31 00:00:00  2015-08-03
# 4  ЗУБ КОВША 1085.52.05-1СБ НАПЛАВКА  2015-08-31 00:00:00  2015-08-03
#
#    Срок поставки  Плановый срок поставки               Регион  Объем заказа  \
# 0          671.0                   210.0   Республика Карелия             1
# 1           99.0                   180.0  Вологодская область             1
# 2           85.0                   150.0  Вологодская область             1
# 3           28.0                    30.0  Вологодская область             6
# 4           28.0                    75.0  Вологодская область            30
#
#       Цена, руб                                    Условия платежа  \
# 0  3.839490e+04  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 30 дней с да...
# 1  2.050955e+06  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 60 дней с да...
# 2  1.337580e+06  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 60 дней с да...
# 3  3.439490e+03  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 60 дней с да...
# 4  6.496815e+03  ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 60 дней с да...
#
#    НРП - нерегламентная потребность (внеплановая закупка)  Поставщик  \
# 0                                                NaN            4011
# 1                                                NaN            3699
# 2                                                NaN            3699
# 3                                                NaN            3699
# 4                                                NaN            3699
#
#                        Наименование2
# 0  шкив к мпэ-350-900 3536-19-00-200
# 1                стрела 1085-05-00сб
# 2            устройство куэ-3 04ухл2
# 3                  втулка 1080-33-70
# 4  зуб ковша 1085-52-05-1сб наплавка

# %%
df.Наименование2.nunique()
# Out:
# 956

# %%
# clean names
sub_dict = {
    r"(зуб)\s(.*)\s*(ковша)\s*(.+)": r"\1 \3 \2 \4",
    ",* *с наплавкой": " наплавка",
    "венец зубчатый": "венец зубч",
    r"блоки голов-": "блоки голов",
    r"блоки головные": "блоки голов",
    r"блоки отклон-": "блоки отклон",
    r"блок-шестерня(\d)": r"блок-шестерня \1",
    r"блок(\d)": "блок \\1",    # TODO: "блок3"
    r"блок3": "блок 3",
    "блок управления": "блок упр",
    r"блок,": "блок",
    "блоки ": "блок ",
    "блок головной": "блок голов",
    "венец3": "венец 3",
    r"венец(\d)": "венец \\1",
    r"втулка(\d)": "втулка \\1",
    # TODO: "днище"
    r"засов(\d)": "засов \\1",
    r"звено(\d)": "звено \\1",
    r"зуб(\d)": "зуб \\1",
    r"ковш(\d)": "ковш \\1",
    r"колесо(\d)": "колесо \\1",
    r"^([а-яa-z]+)(\d)": "\\1 \\2",
    # TODO: колесо
    "- ": " ",
    "   ": " ",
    "  ": " ",
    " ,": ",",
    r",(\S)": r", \1", 
}

df['Наименование3'] = df.Наименование2

for k, v in sub_dict.items():
    df.Наименование3 = df.Наименование3.apply(lambda s: re.sub(k, v, s))

# %% [markdown]
# # Group Items

# %%
group_dict = {
    "амортизатор \d": "амортизатор",
    "барабан \d": "барабан",
    "блок \d": "блок",
    "блок голов": "блок голов",
    "блок трмз": "блок трмз",
    "блок упр": "блок упр",
    "блок-шес": "блок-шестерня",
    "болт \d": "болт",
    "бронь конуса": "бронь конуса",
    "вал \d": "вал",
    "вал веду": "вал ведущий",
    "вал промеж": "вал промежуточный",
    "вал трмз": "вал трмз",
    "вал-шест": "вал-шестерня",
    "вант ": None,
    "венец зубч": "венец зубч",
    "венец \d": "венец",
    "вентилятор": None,
    "винт": None,
    "вкладыш": None,
    "водило": None,
    "втулка \d": "втулка",
    "втулка бронз": None,
    "втулка колеса": None,
    "втулка напорной оси": None,
    "втулка сзсм": None,
    "втулка трубы": None,
    "г/цил": None,
    "гайка": None,
    "джойстик": None,
    "днище": None,
    "засов": None,
    "звездочка": None,
    "звено": None,
    "зуб": None,
    "изолятор": None,
    "клин": None,
    "ковш": None,
    "колесо": None
}

df['Группа'] = None
for k, v in group_dict.items():
    df.Группа = df.apply(
        lambda r: 
        (v if v else k)
        if (
            re.search(k, r.Наименование3) 
            and re.search(k, r.Наименование3).start() == 0 
        )
        else r.Группа,
        axis=1 
    )
    
names_out = df[['Наименование', 'Наименование3', 'Группа']]
names_out.drop_duplicates(subset='Наименование3', inplace=True)
names_out = names_out.sort_values('Наименование3', ascending=True)
names_out.to_excel('tmp.xlsx', index=False)

# l = list(names_out[names_out.str.contains('блок3')].values)[0]
# l
# Out:
# C:\Users\kan\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# # Payment terms

# %%
df['Условия платежа'].unique()
# Out:
# array(['ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 30 дней с даты ППС ДЕНЬГИ 100%',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 60 дней с даты ППС ДЕНЬГИ 100%',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 45 дней с даты ППС ДЕНЬГИ 100%',
#        nan,
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 10 дней с даты ППС ДЕНЬГИ 100%',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100 % в течение 20 дней с даты перехода права собственности (ППС)  ДЕНЬГИ 100% ',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 10 дней с даты счета-фактуры ДЕНЬГИ 100%',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 80 дней с даты ППС ',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100 % в течение 5 дней с даты счета-фактуры  ДЕНЬГИ 100% ',
#        'ПРЕДОПЛАТА 100% в течение 10 дней с даты счета на предоплату ',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 15 дней с даты ППС ДЕНЬГИ 100%',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 30 дней с даты счета-фактуры ДЕНЬГИ 100%',
#        'ПОСЛЕДУЮЩАЯ ОПЛАТА 100% в течение 60 дней с даты счета-фактуры ДЕНЬГИ 100%'],
#       dtype=object)

# %% [markdown]
# Looks fine. Not touched.

# %% [markdown]
# # Delivery dates

# %%
df[df['Дата поставки'].isnull()]
# Out:
#                                Наименование Дата поставки Дата заказа  \
# 2402             Редуктор  3555.11.01.000СБ           NaN         NaT
# 2403             Редуктор  3555.11.01.000СБ           NaN         NaT
# 2414     РУКОЯТЬ ФЛАНЦЕВАЯ 3536.38.00.000СБ           NaN         NaT
# 2489                   Блок  3536.03.00.150           NaN         NaT
# 2515                Вал ТРМЗ 3572.05.10.200           NaN         NaT
# 2569                    Вал  3532.10.01.011           NaN         NaT
# 2730                Лебедка  3536.08.00.000           NaN         NaT
# 2980           Обойма ТРМЗ 3532.21.00.100СБ           NaN         NaT
# 3458  Вал-шестерня Z=12 черт.3537.67.01.023           NaN         NaT
# 3459    Вал-ведущий  черт.3550.05.02.046-02           NaN         NaT
#
#       Срок поставки  Плановый срок поставки              Регион  Объем заказа  \
# 2402            NaN                   330.0  Республика Карелия             1
# 2403            NaN                   330.0  Республика Карелия             1
# 2414            NaN                   200.0  Республика Карелия             2
# 2489            NaN                   100.0  Республика Карелия             4
# 2515            NaN                   220.0  Республика Карелия            10
# 2569            NaN                   160.0  Республика Карелия             6
# 2730            NaN                   330.0  Республика Карелия             1
# 2980            NaN                   200.0  Республика Карелия             2
# 3458            NaN                     NaN  Республика Карелия             2
# 3459            NaN                     NaN  Республика Карелия             2
#
#          Цена, руб Условия платежа  \
# 2402  1.496815e+06             NaN
# 2403  1.624204e+06             NaN
# 2414  1.902548e+06             NaN
# 2489  2.675159e+05             NaN
# 2515  2.625478e+05             NaN
# 2569  1.121019e+05             NaN
# 2730  4.299363e+06             NaN
# 2980  2.484076e+05             NaN
# 3458  4.757962e+05             NaN
# 3459  5.095541e+05             NaN
#
#       НРП - нерегламентная потребность (внеплановая закупка)  Поставщик  \
# 2402                                                NaN            4014
# 2403                                                NaN            4012
# 2414                                                NaN            4014
# 2489                                                NaN            4014
# 2515                                                NaN            4014
# 2569                                                NaN            4014
# 2730                                                NaN            4014
# 2980                                                NaN            4014
# 3458                                                NaN            4014
# 3459                                                NaN            4014
#
#                               Наименование2
# 2402               редуктор3555-11-01-000сб
# 2403               редуктор3555-11-01-000сб
# 2414     рукоять фланцевая 3536-38-00-000сб
# 2489                     блок3536-03-00-150
# 2515                вал трмз 3572-05-10-200
# 2569                      вал3532-10-01-011
# 2730                  лебедка3536-08-00-000
# 2980           обойма трмз 3532-21-00-100сб
# 3458  вал-шестерня z=12 черт-3537-67-01-023
# 3459      вал-ведущийчерт-3550-05-02-046-02

# %% [markdown]
# Can't use rows with empty delivery date.

# %%
df = df[df['Дата поставки'].notnull()]

# %% [markdown]
# # Order date

# %%
sum(df['Дата заказа'].isnull())
# Out:
# 1066

# %%
df['Дата заказа'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4010    False
# 4011    False
# 4012    False
# 4013    False
# 4014    False
# Name: Дата заказа, Length: 4005, dtype: bool
